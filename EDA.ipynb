# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
print("loade")
wr.filterwarnings('ignore')
# Out:
# loade

# %% [markdown]
# Data Inspection: Check the size of the dataset, how it is organized, the types of data it contains and basic summary values.
# Handling Missing and Duplicate Data: Find and fix empty values or repeated rows to keep the data clean.
# Univariate Analysis: Study one variable at a time to understand its distribution, trend and outliers.
# Bivariate Analysis: Compare two variables to see how they are related.
# Multivariate Analysis: Analyze three or more variables together to understand deeper relationships.

# %%
# load data set
df = pd.read_csv("products-100.csv")
print(df.head())
# Out:
#    Index                                  Name  \
# 0      1  Compact Printer Air Advanced Digital
# 1      2                                Tablet
# 2      3                  Smart Blender Cooker
# 3      4          Advanced Router Rechargeable
# 4      5          Portable Mouse Monitor Phone
#
#                                          Description  \
# 0      Situation organization these memory much off.
# 1        Discussion loss politics free one thousand.
# 2                                  No situation per.
# 3                    For force gas energy six laugh.
# 4  Feeling back religious however author room sci...
#
#                         Brand            Category  Price Currency  Stock  \
# 0     Garner, Boyle and Flynn  Books & Stationery    265      USD    774
# 1                 Mueller Inc    Shoes & Footwear    502      USD     81
# 2  Lawson, Keller and Winters  Kitchen Appliances    227      USD    726
# 3          Gallagher and Sons  Kitchen Appliances    121      USD    896
# 4                   Irwin LLC      Kids' Clothing      1      USD    925
#
#              EAN        Color        Size  Availability  Internal ID
# 0  2091465262179  ForestGreen       Large     pre_order           56
# 1  5286196620740        Black     8x10 in      in_stock           29
# 2  1282898648918    SlateGray          XS      in_stock           70
# 3  3879177514583    PaleGreen           L  discontinued           31
# 4  9055773261265     SeaShell  100x200 mm  discontinued           10

# %%
# analize the data 
print("SHAPE")
df.shape
print("\n INFO \n\n\n")
df.info()
# Out:
# SHAPE
#
#  INFO
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Index         100 non-null    int64
#  1   Name          100 non-null    object
#  2   Description   100 non-null    object
#  3   Brand         100 non-null    object
#  4   Category      100 non-null    object
#  5   Price         100 non-null    int64
#  6   Currency      100 non-null    object
#  7   Stock         100 non-null    int64
#  8   EAN           100 non-null    int64
#  9   Color         100 non-null    object
#  10  Size          100 non-null    object
#  11  Availability  100 non-null    object
#  12  Internal ID   100 non-null    int64
# dtypes: int64(5), object(8)
# memory usage: 10.3+ KB

# %%
# describe the data
df.describe
# Out:
# <bound method NDFrame.describe of     Index                                   Name  \
# 0       1   Compact Printer Air Advanced Digital
# 1       2                                 Tablet
# 2       3                   Smart Blender Cooker
# 3       4           Advanced Router Rechargeable
# 4       5           Portable Mouse Monitor Phone
# ..    ...                                    ...
# 95     96                                 Router
# 96     97     Fast Thermostat Microphone Scooter
# 97     98  Eco Heater Toaster Stove Silent Sense
# 98     99               Clean Blender Scale Lite
# 99    100                             Smart Lamp
#
#                                           Description  \
# 0       Situation organization these memory much off.
# 1         Discussion loss politics free one thousand.
# 2                                   No situation per.
# 3                     For force gas energy six laugh.
# 4   Feeling back religious however author room sci...
# ..                                                ...
# 95                   Investment everything story buy.
# 96                     Nature notice themselves news.
# 97                   Understand still or summer rule.
# 98                               Final art some push.
# 99                         However public major baby.
#
#                           Brand                Category  Price Currency  \
# 0       Garner, Boyle and Flynn      Books & Stationery    265      USD
# 1                   Mueller Inc        Shoes & Footwear    502      USD
# 2    Lawson, Keller and Winters      Kitchen Appliances    227      USD
# 3            Gallagher and Sons      Kitchen Appliances    121      USD
# 4                     Irwin LLC          Kids' Clothing      1      USD
# ..                          ...                     ...    ...      ...
# 95                 Atkinson Inc     Laptops & Computers    375      USD
# 96                     Shea Ltd  Beauty & Personal Care    289      USD
# 97                     West Ltd       Cleaning Supplies    232      USD
# 98     Bell, Gamble and Barrett        Camping & Hiking    241      USD
# 99  Hebert, Hughes and Trujillo          Bedding & Bath     71      USD
#
#     Stock            EAN        Color         Size   Availability  Internal ID
# 0     774  2091465262179  ForestGreen        Large      pre_order           56
# 1      81  5286196620740        Black      8x10 in       in_stock           29
# 2     726  1282898648918    SlateGray           XS       in_stock           70
# 3     896  3879177514583    PaleGreen            L   discontinued           31
# 4     925  9055773261265     SeaShell   100x200 mm   discontinued           10
# ..    ...            ...          ...          ...            ...          ...
# 95    703  3330396409604    Gainsboro      8x10 in  limited_stock           55
# 96    727  9265397743935        White  Extra Large      backorder           25
# 97    998  5505866454530      OldLace        Small  limited_stock           20
# 98    391  3893594435450   Aquamarine       5x7 in  limited_stock            5
# 99    518  8264263605712        Brown       Medium  limited_stock            3
#
# [100 rows x 13 columns]>

# %%
df.describe().T
# Out:
#              count          mean           std          min           25%  \
# Index        100.0  5.050000e+01  2.901149e+01          1.0  2.575000e+01
# Price        100.0  4.511900e+02  2.816091e+02          1.0  2.307500e+02
# Stock        100.0  5.457100e+02  2.667169e+02         10.0  3.475000e+02
# EAN          100.0  4.876267e+12  2.918084e+12  524638185.0  2.062323e+12
# Internal ID  100.0  4.934000e+01  2.807825e+01          3.0  2.500000e+01
#
#                       50%           75%           max
# Index        5.050000e+01  7.525000e+01  1.000000e+02
# Price        4.075000e+02  6.790000e+02  9.990000e+02
# Stock        5.755000e+02  7.492500e+02  9.980000e+02
# EAN          4.875720e+12  7.676943e+12  9.921752e+12
# Internal ID  4.800000e+01  7.450000e+01  9.900000e+01

# %%
df.columns.tolist() # view the column list present in the given dataset
# Out:
# ['Index',
#  'Name',
#  'Description',
#  'Brand',
#  'Category',
#  'Price',
#  'Currency',
#  'Stock',
#  'EAN',
#  'Color',
#  'Size',
#  'Availability',
#  'Internal ID']

# %%
df.isnull().sum()
# Out:
# Index           0
# Name            0
# Description     0
# Brand           0
# Category        0
# Price           0
# Currency        0
# Stock           0
# EAN             0
# Color           0
# Size            0
# Availability    0
# Internal ID     0
# dtype: int64

# %%
# check the data duplicate 
df.nunique()
# Out:
# Index           100
# Name             99
# Description     100
# Brand           100
# Category         32
# Price            96
# Currency          1
# Stock            96
# EAN             100
# Color            72
# Size             17
# Availability      6
# Internal ID      66
# dtype: int64

# %%
quality_counts = df['Category'].value_counts()

plt.figure(figsize=(8, 6))
plt.bar(quality_counts.index, quality_counts, color='red')
plt.title('Analisis')
plt.xlabel('Category')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(15, 10))

sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='Pastel2', linewidths=2)

plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 plt.figure(figsize=(15, 10))
# ----> 3 sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='Pastel2', linewidths=2)
#       5 plt.title('Correlation Heatmap')
#       6 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
#    2000     result = np.asarray(result, dtype=dtype)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Compact Printer Air Advanced Digital'

# %%
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.show()
#
# NameError: name 'plt' is not defined
