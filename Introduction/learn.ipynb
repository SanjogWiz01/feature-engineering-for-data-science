# %% [markdown]
# feature enginnering _ make machine easy to learn and understnas dthe data for better results
# eature Engineering = preparing raw data so machine learning models can learn better.

# %% [markdown]
# clean
# transform
# useful features
# models

# %% [markdown]
# convert the code into numbers
